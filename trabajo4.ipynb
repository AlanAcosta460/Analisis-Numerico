# %% [markdown]
# # Trabajo 4

# %% [markdown]
# ### Ecuaciones algebraicas y trascendentales

# %%
red = 4
tol = 0.0001
max_iter = 25

def biseccion() :
    print("*** Bisección ***")
    print("La función es: 0.5x^3 - 2x^2 + 3x - 90 = 0")

    print(f"Con tolerancia = {tol} y maximo de iteraciones = {max_iter}\n")
    tabular(4)

    while True:
        xI = float(input("\n*** Ingresa el valor inicial xI *** \n$ "))
        xS = float(input("\n*** Ingresa el valor final xS *** \n$ "))

        fxI = f(xI)
        fxS = f(xS)

        if fxI * fxS >= 0 :
            print("\n\tEl intervalo no es valido\n")
        else :
            break

    print("\n\ni\txI\t\txP\t\txS\t\tf(xI)\t\tf(xP)\t\tf(xS)\t\t|xS - xI|\tvs tol")
    i = 1
    diff = 1
    while diff <= tol or i <= max_iter:
        xP = round((xI + xS) / 2, red)
        fxI = f(xI)
        fxS = f(xS)
        fxP = f(xP)

        dif = round(abs(xS - xI), red)
        print(f"{i}\t{xI}\t\t{xP}\t\t{xS}\t\t{fxI}    \t{fxP}    \t{fxS}\t\t{dif}\t\t{'Cumple' if dif <= tol else 'No cumple'}")

        if fxI * fxP < 0 :
            xS = xP
        else :
            xI = xP

        i += 1

    print(f"\n*** Raiz = {xP} ***")


def falsa_posicion() :
    print("*** Falsa Posición ***")
    print("La función es: 0.5x^3 - 2x^2 + 3x - 90 = 0")

    print(f"Con tolerancia = {tol} y maximo de iteraciones = {max_iter}\n")
    tabular(4)

    while True :
        xI = float(input("\n*** Ingresa el valor inicial xI *** \n$ "))
        xS = float(input("\n*** Ingresa el valor final xS *** \n$ "))

        fxI = f(xI)
        fxS = f(xS)

        if fxI * fxS >= 0 :
            print("\n\tEl intervalo no es valido\n")
        else :
            break

    print("\n\ni\txI\t\txP\t\txS\t\tf(xI)\t\tf(xP)\t\tf(xS)\t\t|xS - xI|\tvs tol")
    i = 1
    diff = 1
    while diff <= tol or i <= max_iter:
        xP = round(xS - (fxS * (xI - xS)) / (fxI - fxS), red)
        fxI = f(xI)
        fxS = f(xS)
        fxP = f(xP)

        dif = round(abs(xS - xI), red)
        print(f"{i}\t{xI}\t\t{xP}\t\t{xS}\t\t{fxI}    \t{fxP}    \t{fxS}\t\t{dif}\t\t{'Cumple' if dif <= tol else 'No cumple'}")

        if fxI * fxP < 0 :
            xS = xP
        else :
            xI = xP

        if dif <= tol :
            break

        i += 1

    print(f"\n*** Raiz = {xP} ***")


def newton_raphson() :
    print("*** Newton-Raphson ***")
    print("La función es: 0.5x^3 - 2x^2 + 3x - 90 = 0")

    print(f"Con tolerancia = {tol}, maximo de iteraciones = {max_iter}\n")
    tabular(4)

    while True:
        try:
            x0 = float(input("\n*** Ingresa el valor inicial *** \n$ "))
            
            criterio = G_1(x0)
            print("\n\n*** Prueba de Convergencia ***")
            print(f"x0 = {x0}\t|G'1(x0)| = {abs(criterio)}")

            if abs(criterio) >= 1:
                print("\n\tEl método de Newton-Raphson no converge\n") 
            else:
                print("\n\tEl método de Newton-Raphson converge\n")
                break
        except ValueError:
            print("\t Ingresa un número válido \n")
            
    arr = [float(x0)]
    i = 0  
    dif = 1

    print("i\tx_i\t\tf(x_i)\t\tf'(x_i)\t\tG(x_i)\t\tx_(i+1) - x_i\tvs tol")
    while dif > tol and i <= max_iter: 
        arr.append(G(arr[i]))
        dif = round(abs(arr[i + 1] - arr[i]), red)
        
        print(f"{i}\t{arr[i]}      \t{f(arr[i])}      \t{f_1(arr[i])}    \t{arr[i + 1]}    \t{dif}      \t{'Cumple' if dif <= tol else 'No cumple'}")
        i += 1

    print(f"\n*** Raiz = {arr[i]} ***")


def secante() :
    print("*** Secante ***")
    print("La función es: 0.5x^3 - 2x^2 + 3x - 90 = 0")

    print(f"Con tolerancia = {tol} y maximo de iteraciones = {max_iter}\n")
    tabular(4)

    while True:
        x0 = float(input("\n*** Ingresa el valor inicial x0 *** \n$ "))
        x1 = float(input("\n*** Ingresa el valor inicial x1 *** \n$ "))

        fx0 = f(x0)
        fx1 = f(x1)

        if fx0 * fx1 >= 0 :
            print("\n\tEl intervalo no es valido\n")
        else :
            break

    i = 1
    dif = 1
    print("\n\ni\tx_(i-1)\t\tx_i\t\tf(x_(i-1))\tf(x_i)\t\tx_(i+1)\t\t|x_(i+1) - x_i|\tvs tol")
    while dif > tol and i <= max_iter:
        x2 = round(x1 - (fx1 * (x0 - x1)) / (fx0 - fx1), red)
        fx2 = f(x2)

        dif = round(abs(x2 - x1), red)
        print(f"{i}\t{x0}\t\t{x1}\t\t{fx0}\t\t{fx1}\t\t{x2}\t\t{dif}\t\t{'Cumple' if dif <= tol else 'No cumple'}")

        x0 = x1
        x1 = x2
        fx0 = fx1
        fx1 = fx2

        i += 1

    print(f"\n*** Raiz = {x2} ***")



def f(x) :
    return round(0.5*(x ** 3) - 2*(x ** 2) + 3*x - 90, red)

def f_1(x) :
    return round(1.5*(x ** 2) - 4*x + 3, red)

def f_2(x) :
    return round(3*x - 4, red)

def G(x) :
    return round(x - (f(x) / f_1(x)), red)

def G_1(x) :
    return round((f(x) * f_2(x)) / (f_1(x) ** 2), red)

def tabular(inicio) :
    print("***** Tabulacion *****")
    print("x\tf(x)\t\tx\tf(x)\t\tx\tf(x)\t\tx\tf(x)\t\tx\tf(x)")

    for i in range(0, 10) :
        for j in range(0, 5) :
            x = inicio + (0.1 * i) + (0.1 * (10 * j))
            print(f"{round(x, red)}\t{round(f(x), red)}", end='     \t')
        print()

# %% [markdown]
# ### Sistemas de ecuaciones

# %%
import numpy as np

A = np.array([[10, 2, 6], [1, 10, 9], [2, -7, -10]])
B = np.array([7, -17, 28])
tol = 0.0001
max_iter = 25
red = 4

def gauss_seidel() :
    print("*** Gauss-Seidel ***")

    print("%%% Sistema de Ecuaciones %%%")
    print("10x + 2y + 6z = 7")
    print("x + 10y + 9z = -17")
    print("2x - 7y - 10z = 28")

    print("\n%%% Criterio de Convergencia %%%")
    print("|A_(ii)| > |A_(ij)|")
    print("10 > 2\t\t10 > 6\n10 > 1\t\t10 > 9\n10 > 2\t\t10 > 7\n")
    print("\n|A_(ii)| > |A_(ij)| + |A_(ik)|")
    print("10 > 2 + 6 ==> 10 > 8\n10 > 1 + 9 ==> 10 >/ 10\n10 > 2 + 7 ==> 10 > 9\n")

    print("\n\t\tEl metodo converge")

    x1 = np.zeros_like(3)
    x2 = np.zeros_like(3)

    i = 1
    x = 0
    y = 0
    z = 0
    band = true
    while band or i <= max_iter:
        x2[0] = round((b[0] - A[0][1]*x1[1] - A[0][2]*x1[2]) / A[0][0], red)
        x2[1] = round((b[1] - A[1][0]*x2[0] - A[1][2]*x1[2]) / A[1][1], red)
        x2[2] = round((b[2] - A[2][0]*x2[0] - A[2][1]*x2[1]) / A[2][2], red)

        x1 = x2
        band = true
        for k in x1 :
            band &= k > tol
        

    print(f"\n*** Solucion = {x} ***")

# %% [markdown]
# ### Integracion numerica

# %%
def trapecial() :
    a = 0

def simpson_13() :
    a = 0

def simpson_38() :
    a = 0

# %% [markdown]
# ### Ecuaciones diferenciales

# %%
def euler() :
    a = 0

def euler_gauss() :
    a = 0

def runge_kutta() :
    a = 0

# %% [markdown]
# ### Sistema

# %%
def presentacion() :
    print("****************************************************")
    print("\n\t\t ANÁLISIS NUMÉRICO")
    print("\t\t      GRUPO 4")
    print("\t\t     TRABAJO 4\n") 
    print("****************************************************")

    print("\n\n*** Integrantes del equipo ***")
    print("- Acosta Porcayo Alan Omar")
    print("- Alvarez González Eduardo")
    print("- Hernández Castillo Rubén")


def menu() :
    print("\n\t\t%%% MENU %%%")

    print("1) Ecuaciones algebraicas y trascendentales")
    print("2) Sistemas de ecuaciones")
    print("3) Intregacion numerica")
    print("4) Ecuaciones diferenciales")

    j = 'b'
    op = opcion(1, 4)
    match op :
        case 1 :
            print("1) Biseccion")
            print("2) Falsa Posicion")
            print("3) Newton-Raphson")
            print("4) Secante")
            j = 4
        case 2 : 
            print("1) Gauss-Seidel")
            j = 1
        case 3 :
            print("1) Trapecial")
            print("2) Simpson 1/3")
            print("3) Simpson 3/8")
            j = 3
        case 4 :
            print("1) Metodo de Euler")
            print("2) Metodo de Euler-Gauss")
            print("3) Metodo de Runge Kutta de 4to orden")
            j = 3 

    op = str(op) + str(opcion(1, j))
    ejecutar(op)

def opcion(i, j) :
    while (True) :
        op = int(input(f"Ingrese una opcion ({i}-{j}) $ "))

        if op < i or op > j :
            print("\n\tOpcion invalida\n")
        else :
            break
    print()
    return op

def ejecutar(comando) :
    match comando :
        case "11" :
            biseccion()
        case "12" :
            falsa_posicion() 
        case "13" :
            newton_raphson()
        case "14" :
            secante()

        case "21" :
            gauss_seidel()

        case "31" :
            trapecial() 
        case "32" :
            simpson_13()
        case "33" :
            simpson_38()
        
        case "41" :
            euler()
        case "42" :
            euler_gauss()
        case "43" :
            runge_kutta()

def main() :
    presentacion()

    while (True) :
        menu()
        
        op = input("\n\n\t\tDesea volver a utilizar el programa? (s/n) $ ")
        if op != "s" :
            break
        print()

    print("\nGracias por usar el programa!!!")

if __name__ == "__main__" :
    main()
# Out:
# ****************************************************
#
# 		 ANÁLISIS NUMÉRICO
# 		      GRUPO 4
# 		     TRABAJO 4
#
# ****************************************************
#
#
# *** Integrantes del equipo ***
# - Acosta Porcayo Alan Omar
# - Alvarez González Eduardo
# - Hernández Castillo Rubén
#
# 		%%% MENU %%%
# 1) Ecuaciones algebraicas y trascendentales
# 2) Sistemas de ecuaciones
# 3) Intregacion numerica
# 4) Ecuaciones diferenciales
#
# 1) Biseccion
# 2) Falsa Posicion
# 3) Newton-Raphson
# 4) Secante
#
# *** Secante ***
# La función es: 0.5x^3 - 2x^2 + 3x - 90 = 0
# Con tolerancia = 0.0001 y maximo de iteraciones = 25
#
# ***** Tabulacion *****
# x	f(x)		x	f(x)		x	f(x)		x	f(x)		x	f(x)
# 4.0	-78.0     	5.0	-62.5     	6.0	-36.0     	7.0	4.5     	8.0	62.0
# 4.1	-76.8595     	5.1	-60.3945     	6.1	-32.6295     	7.1	9.4355     	8.1	68.8005
# 4.2	-75.636     	5.2	-58.176     	6.2	-29.116     	7.2	14.544     	8.2	75.804
# 4.3	-74.3265     	5.3	-55.8415     	6.3	-25.4565     	7.3	19.8285     	8.3	83.0135
# 4.4	-72.928     	5.4	-53.388     	6.4	-21.648     	7.4	25.292     	8.4	90.432
# 4.5	-71.4375     	5.5	-50.8125     	6.5	-17.6875     	7.5	30.9375     	8.5	98.0625
# 4.6	-69.852     	5.6	-48.112     	6.6	-13.572     	7.6	36.768     	8.6	105.908
# 4.7	-68.1685     	5.7	-45.2835     	6.7	-9.2985     	7.7	42.7865     	8.7	113.9715
# 4.8	-66.384     	5.8	-42.324     	6.8	-4.864     	7.8	48.996     	8.8	122.256
# 4.9	-64.4955     	5.9	-39.2305     	6.9	-0.2655     	7.9	55.3995     	8.9	130.7645
#
#
# i	x_(i-1)		x_i		f(x_(i-1))	f(x_i)		x_(i+1)		|x_(n+1) - x_n|	vs tol
# 1	5.0		7.0		-62.5		4.5		6.8657		0.1343		No cumple
# 2	7.0		6.8657		4.5		-1.8615		6.905		0.0393		No cumple
# 3	6.8657		6.905		-1.8615		-0.0312		6.9057		0.0007		No cumple
# 4	6.905		6.9057		-0.0312		0.0016		6.9057		0.0		Cumple
#
# *** Raiz = 6.9057 ***
#
# Gracias por usar el programa!!!
